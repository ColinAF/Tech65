# %% [markdown]
# # Exploring Data
# ## Data Structure
# We want to keep track of how the data maps to the raw throughout the whole process
#     1. raw data
#         - To trace explinations back to raw data
#     2. cleaned up
#         - For analysis
#     3. Predictive model
#          - For other derived columns
# ## Data Types
#  - Categorical Data -> Finite Set of catagoires
#     - Value Counts
#     - Bar Plots
#  - Numeric Data -> Real or Integer numbers
#     - Mean
#     - Max - Min
#     - Histograms may have gaps if you change the number of bins
#     - Look at corrilations between the columns
# - Categorical vs Numerical
# - Categorical vs Categorical
#     - Crosstabulation
#     - Stacked bar chart
# # Extra
#  - Seaborn boxenplot is a more modern version of a box plot

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import io
import urllib.request as req
import zipfile
